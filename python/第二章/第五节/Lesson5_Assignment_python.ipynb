# %% [markdown]
# ![image alt <](https://img.kaikeba.com/web/kkb_index/img_index_logo.png )

# %% [markdown]
# # 基础课第一部分（python）第五次作业
#
# 这周我们学习了面向对象的编程，面向对象的编程常常使用在游戏开发中。我们本次作业将对抗游戏中的角色建立，简单攻击做了简化展示，同学们首先需要将这两部分内容仔细阅读和学习，之后的练习中武器配给及完整对抗攻击我们只会给出框架，更多的过程需要大家自己完成。

# %% [markdown]
# 角色建立考虑到角色的共性和特性，将所有角色的基本共性（包括name, damage, hp）集合到People 类中，作为所有角色的父类

# %%
class People:
    def __init__(self, name, damage, hp):
        self.name=name
        self.damage=damage
        self.hp=hp

# %% [markdown]
# 针对不同阵营的英雄，在继承People类的基础上添加country属性。同时，建立了显示实例基本信息的方法 get_inf 和攻击其他实例的方法 attack。

# %%
class Hero(People):
    def __init__(self, name, damage, hp, country):
        People.__init__(self, name, damage, hp)
        self.country=country   
        
    def get_inf(self):
        print("姓名：{}".format(self.name))
        print("攻击力：{}".format(self.damage))
        print("当前血量：{}".format(self.hp))
        print("阵营：{}".format(self.country))

    def attack(self,enemy):
        print(self.name)
        print("攻击力为：{}".format(self.damage))
        print("{}目前血量为：{}".format(enemy.name, enemy.hp))
        print("{}攻击{}".format(self.name,enemy.name))
        enemy.hp-=self.damage
        print("{}剩余血量为：{}".format(enemy.name, enemy.hp))
        print("***********************************")

# %% [markdown]
# 接下来，我们尝试创建People 的实例 XB 和 Hero 类实例 LB 和 ZF。

# %%
XB = People("小兵", 1, 10)
LB=Hero("吕布", 20, 100, "群雄")
ZF=Hero("张飞", 7, 80, "蜀国")

# %% [markdown]
# 实例创建完成之后，我们调用Hero 类中的方法 get_ing 查看实例 ZF 的基本信息。
# 请同学们思考实例 XB 能否调用该方法，为什么？

# %%
ZF.get_inf()
# Out:
# 姓名：张飞
# 攻击力：7
# 当前血量：80
# 阵营：蜀国

# %% [markdown]
# 调用attack方法，让“ZF”攻击“LB”

# %%
ZF.attack(LB)
# Out:
# 张飞
# 攻击力为：7
# 吕布目前血量为：100
# 张飞攻击吕布
# 吕布剩余血量为：93
# ***********************************

# %% [markdown]
# # 练习1
#
# 这部分需要同学们新建一个武器类,同时能够将武器赋予某个实例，用以提升攻击力。

# %% [markdown]
# 属性：武器名称、武器伤害值

# %% [markdown]
# 方法：把武器给予某位英雄，赠予后该英雄攻击力为基础攻击力加武器伤害值

# %%
class Weapon:
    def __init__(self, name, damage):
        """武器基础属性"""
        self.name=name
        self.damage=damage

    def take_weapon(self, hro):
        """将武器给予英雄，英雄攻击力提升"""
        print("将武器{}装备给英雄{}".format(self.name, hro.name))
        hro.damage+=self.damage
        print("{}的攻击力变为{}".format(hro.name, hro.damage))

# %% [markdown]
# # 练习2
#
#  - 新建武器实例,其中包含属性：名称（丈八蛇矛）、伤害值（3）
#  - 将武器赠与张飞

# %%
snake_weapon=Weapon("丈八蛇矛", 3)
snake_weapon.take_weapon(ZF)
# Out:
# 将武器丈八蛇矛装备给英雄张飞
# 张飞的攻击力变为10

# %% [markdown]
# # 练习3
#
# - 显示“ZF”目前信息
# - 令“ZF”攻击“LB”

# %%
print("{0}“ZF”目前信息{1}".format(15*'*',15*'*'))
ZF.get_inf()
print("{0}“ZF”攻击“LB”{1}".format(15*'*',15*'*'))
ZF.attack(LB)
# Out:
# ***************“ZF”目前信息***************
# 姓名：张飞
# 攻击力：10
# 当前血量：80
# 阵营：蜀国
# ***************“ZF”攻击“LB”***************
# 张飞
# 攻击力为：10
# 吕布目前血量为：93
# 张飞攻击吕布
# 吕布剩余血量为：83
# ***********************************

# %% [markdown]
# # 提升练习 --“群英战吕布”
#
# 框架：
# 建立群英（多个hero实例）及吕布实例（属性值设置合理）
# 让一个英雄（英雄1）与吕布持续战斗，当英雄1血量小于吕布攻击时，英雄1失败逃跑
# 英雄1回复血量，同时加入英雄2，与吕布持续战斗，当。。。。
# 持续添加英雄，直到吕布逃跑

# %%
# 补充完善本代码块（实现指定功能即可）
i = 0
first_hero = Hero('hero'+str(i), 15, 30, "反吕联盟")
heros = {'hero'+str(i):first_hero}
super_LB = Hero("吕布",10,1000,"群雄")
while super_LB.hp>=1:
    hero=heros['hero'+str(i)]
    print('{0}第{1}位英雄出场{2}'.format(22*'=',i+1,22*'='))
    while hero.hp>=1:
        hero.attack(super_LB)
        if super_LB.hp>=1:
            # 判断吕布血量是否可以继续战斗
            super_LB.attack(hero)
        else:
            break
    else:
        print('{0}第{1}位英雄失败逃跑{2}'.format(20*'=',i+1,20*'='))
    
    i += 1
    new_hero = Hero('hero'+str(i), 15, 30, "反吕联盟")
    heros['hero'+str(i)] = new_hero 
    
print('吕布老矣~~失败逃跑~~88~~')
# Out:
# ======================第1位英雄出场======================
# hero0
# 攻击力为：15
# 吕布目前血量为：1000
# hero0攻击吕布
# 吕布剩余血量为：985
# ***********************************
# 吕布
# 攻击力为：10
# hero0目前血量为：30
# 吕布攻击hero0
# hero0剩余血量为：20
# ***********************************
# hero0
# 攻击力为：15
# 吕布目前血量为：985
# hero0攻击吕布
# 吕布剩余血量为：970
# ***********************************
# 吕布
# 攻击力为：10
# hero0目前血量为：20
# 吕布攻击hero0
# hero0剩余血量为：10
# ***********************************
# hero0
# 攻击力为：15
# 吕布目前血量为：970
# hero0攻击吕布
# 吕布剩余血量为：955
# ***********************************
# 吕布
# 攻击力为：10
# hero0目前血量为：10
# 吕布攻击hero0
# hero0剩余血量为：0
# ***********************************
# ====================第1位英雄失败逃跑====================
# ======================第2位英雄出场======================
# hero1
# 攻击力为：15
# 吕布目前血量为：955
# hero1攻击吕布
# 吕布剩余血量为：940
# ***********************************
# 吕布
# 攻击力为：10
# hero1目前血量为：30
# 吕布攻击hero1
# hero1剩余血量为：20
# ***********************************
# hero1
# 攻击力为：15
# 吕布目前血量为：940
# hero1攻击吕布
# 吕布剩余血量为：925
# ***********************************
# 吕布
# 攻击力为：10
# hero1目前血量为：20
# 吕布攻击hero1
# hero1剩余血量为：10
# ***********************************
# hero1
# 攻击力为：15
# 吕布目前血量为：925
# hero1攻击吕布
# 吕布剩余血量为：910
# ***********************************
# 吕布
# 攻击力为：10
# hero1目前血量为：10
# 吕布攻击hero1
# hero1剩余血量为：0
# ***********************************
# ====================第2位英雄失败逃跑====================
# ======================第3位英雄出场======================
# hero2
# 攻击力为：15
# 吕布目前血量为：910
# hero2攻击吕布
# 吕布剩余血量为：895
# ***********************************
# 吕布
# 攻击力为：10
# hero2目前血量为：30
# 吕布攻击hero2
# hero2剩余血量为：20
# ***********************************
# hero2
# 攻击力为：15
# 吕布目前血量为：895
# hero2攻击吕布
# 吕布剩余血量为：880
# ***********************************
# 吕布
# 攻击力为：10
# hero2目前血量为：20
# 吕布攻击hero2
# hero2剩余血量为：10
# ***********************************
# hero2
# 攻击力为：15
# 吕布目前血量为：880
# hero2攻击吕布
# 吕布剩余血量为：865
# ***********************************
# 吕布
# 攻击力为：10
# hero2目前血量为：10
# 吕布攻击hero2
# hero2剩余血量为：0
# ***********************************
# ====================第3位英雄失败逃跑====================
# ======================第4位英雄出场======================
# hero3
# 攻击力为：15
# 吕布目前血量为：865
# hero3攻击吕布
# 吕布剩余血量为：850
# ***********************************
# 吕布
# 攻击力为：10
# hero3目前血量为：30
# 吕布攻击hero3
# hero3剩余血量为：20
# ***********************************
# hero3
# 攻击力为：15
# 吕布目前血量为：850
# hero3攻击吕布
# 吕布剩余血量为：835
# ***********************************
# 吕布
# 攻击力为：10
# hero3目前血量为：20
# 吕布攻击hero3
# hero3剩余血量为：10
# ***********************************
# hero3
# 攻击力为：15
# 吕布目前血量为：835
# hero3攻击吕布
# 吕布剩余血量为：820
# ***********************************
# 吕布
# 攻击力为：10
# hero3目前血量为：10
# 吕布攻击hero3
# hero3剩余血量为：0
# ***********************************
# ====================第4位英雄失败逃跑====================
# ======================第5位英雄出场======================
# hero4
# 攻击力为：15
# 吕布目前血量为：820
# hero4攻击吕布
# 吕布剩余血量为：805
# ***********************************
# 吕布
# 攻击力为：10
# hero4目前血量为：30
# 吕布攻击hero4
# hero4剩余血量为：20
# ***********************************
# hero4
# 攻击力为：15
# 吕布目前血量为：805
# hero4攻击吕布
# 吕布剩余血量为：790
# ***********************************
# 吕布
# 攻击力为：10
# hero4目前血量为：20
# 吕布攻击hero4
# hero4剩余血量为：10
# ***********************************
# hero4
# 攻击力为：15
# 吕布目前血量为：790
# hero4攻击吕布
# 吕布剩余血量为：775
# ***********************************
# 吕布
# 攻击力为：10
# hero4目前血量为：10
# 吕布攻击hero4
# hero4剩余血量为：0
# ***********************************
# ====================第5位英雄失败逃跑====================
# ======================第6位英雄出场======================
# hero5
# 攻击力为：15
# 吕布目前血量为：775
# hero5攻击吕布
# 吕布剩余血量为：760
# ***********************************
# 吕布
# 攻击力为：10
# hero5目前血量为：30
# 吕布攻击hero5
# hero5剩余血量为：20
# ***********************************
# hero5
# 攻击力为：15
# 吕布目前血量为：760
# hero5攻击吕布
# 吕布剩余血量为：745
# ***********************************
# 吕布
# 攻击力为：10
# hero5目前血量为：20
# 吕布攻击hero5
# hero5剩余血量为：10
# ***********************************
# hero5
# 攻击力为：15
# 吕布目前血量为：745
# hero5攻击吕布
# 吕布剩余血量为：730
# ***********************************
# 吕布
# 攻击力为：10
# hero5目前血量为：10
# 吕布攻击hero5
# hero5剩余血量为：0
# ***********************************
# ====================第6位英雄失败逃跑====================
# ======================第7位英雄出场======================
# hero6
# 攻击力为：15
# 吕布目前血量为：730
# hero6攻击吕布
# 吕布剩余血量为：715
# ***********************************
# 吕布
# 攻击力为：10
# hero6目前血量为：30
# 吕布攻击hero6
# hero6剩余血量为：20
# ***********************************
# hero6
# 攻击力为：15
# 吕布目前血量为：715
# hero6攻击吕布
# 吕布剩余血量为：700
# ***********************************
# 吕布
# 攻击力为：10
# hero6目前血量为：20
# 吕布攻击hero6
# hero6剩余血量为：10
# ***********************************
# hero6
# 攻击力为：15
# 吕布目前血量为：700
# hero6攻击吕布
# 吕布剩余血量为：685
# ***********************************
# 吕布
# 攻击力为：10
# hero6目前血量为：10
# 吕布攻击hero6
# hero6剩余血量为：0
# ***********************************
# ====================第7位英雄失败逃跑====================
# ======================第8位英雄出场======================
# hero7
# 攻击力为：15
# 吕布目前血量为：685
# hero7攻击吕布
# 吕布剩余血量为：670
# ***********************************
# 吕布
# 攻击力为：10
# hero7目前血量为：30
# 吕布攻击hero7
# hero7剩余血量为：20
# ***********************************
# hero7
# 攻击力为：15
# 吕布目前血量为：670
# hero7攻击吕布
# 吕布剩余血量为：655
# ***********************************
# 吕布
# 攻击力为：10
# hero7目前血量为：20
# 吕布攻击hero7
# hero7剩余血量为：10
# ***********************************
# hero7
# 攻击力为：15
# 吕布目前血量为：655
# hero7攻击吕布
# 吕布剩余血量为：640
# ***********************************
# 吕布
# 攻击力为：10
# hero7目前血量为：10
# 吕布攻击hero7
# hero7剩余血量为：0
# ***********************************
# ====================第8位英雄失败逃跑====================
# ======================第9位英雄出场======================
# hero8
# 攻击力为：15
# 吕布目前血量为：640
# hero8攻击吕布
# 吕布剩余血量为：625
# ***********************************
# 吕布
# 攻击力为：10
# hero8目前血量为：30
# 吕布攻击hero8
# hero8剩余血量为：20
# ***********************************
# hero8
# 攻击力为：15
# 吕布目前血量为：625
# hero8攻击吕布
# 吕布剩余血量为：610
# ***********************************
# 吕布
# 攻击力为：10
# hero8目前血量为：20
# 吕布攻击hero8
# hero8剩余血量为：10
# ***********************************
# hero8
# 攻击力为：15
# 吕布目前血量为：610
# hero8攻击吕布
# 吕布剩余血量为：595
# ***********************************
# 吕布
# 攻击力为：10
# hero8目前血量为：10
# 吕布攻击hero8
# hero8剩余血量为：0
# ***********************************
# ====================第9位英雄失败逃跑====================
# ======================第10位英雄出场======================
# hero9
# 攻击力为：15
# 吕布目前血量为：595
# hero9攻击吕布
# 吕布剩余血量为：580
# ***********************************
# 吕布
# 攻击力为：10
# hero9目前血量为：30
# 吕布攻击hero9
# hero9剩余血量为：20
# ***********************************
# hero9
# 攻击力为：15
# 吕布目前血量为：580
# hero9攻击吕布
# 吕布剩余血量为：565
# ***********************************
# 吕布
# 攻击力为：10
# hero9目前血量为：20
# 吕布攻击hero9
# hero9剩余血量为：10
# ***********************************
# hero9
# 攻击力为：15
# 吕布目前血量为：565
# hero9攻击吕布
# 吕布剩余血量为：550
# ***********************************
# 吕布
# 攻击力为：10
# hero9目前血量为：10
# 吕布攻击hero9
# hero9剩余血量为：0
# ***********************************
# ====================第10位英雄失败逃跑====================
# ======================第11位英雄出场======================
# hero10
# 攻击力为：15
# 吕布目前血量为：550
# hero10攻击吕布
# 吕布剩余血量为：535
# ***********************************
# 吕布
# 攻击力为：10
# hero10目前血量为：30
# 吕布攻击hero10
# hero10剩余血量为：20
# ***********************************
# hero10
# 攻击力为：15
# 吕布目前血量为：535
# hero10攻击吕布
# 吕布剩余血量为：520
# ***********************************
# 吕布
# 攻击力为：10
# hero10目前血量为：20
# 吕布攻击hero10
# hero10剩余血量为：10
# ***********************************
# hero10
# 攻击力为：15
# 吕布目前血量为：520
# hero10攻击吕布
# 吕布剩余血量为：505
# ***********************************
# 吕布
# 攻击力为：10
# hero10目前血量为：10
# 吕布攻击hero10
# hero10剩余血量为：0
# ***********************************
# ====================第11位英雄失败逃跑====================
# ======================第12位英雄出场======================
# hero11
# 攻击力为：15
# 吕布目前血量为：505
# hero11攻击吕布
# 吕布剩余血量为：490
# ***********************************
# 吕布
# 攻击力为：10
# hero11目前血量为：30
# 吕布攻击hero11
# hero11剩余血量为：20
# ***********************************
# hero11
# 攻击力为：15
# 吕布目前血量为：490
# hero11攻击吕布
# 吕布剩余血量为：475
# ***********************************
# 吕布
# 攻击力为：10
# hero11目前血量为：20
# 吕布攻击hero11
# hero11剩余血量为：10
# ***********************************
# hero11
# 攻击力为：15
# 吕布目前血量为：475
# hero11攻击吕布
# 吕布剩余血量为：460
# ***********************************
# 吕布
# 攻击力为：10
# hero11目前血量为：10
# 吕布攻击hero11
# hero11剩余血量为：0
# ***********************************
# ====================第12位英雄失败逃跑====================
# ======================第13位英雄出场======================
# hero12
# 攻击力为：15
# 吕布目前血量为：460
# hero12攻击吕布
# 吕布剩余血量为：445
# ***********************************
# 吕布
# 攻击力为：10
# hero12目前血量为：30
# 吕布攻击hero12
# hero12剩余血量为：20
# ***********************************
# hero12
# 攻击力为：15
# 吕布目前血量为：445
# hero12攻击吕布
# 吕布剩余血量为：430
# ***********************************
# 吕布
# 攻击力为：10
# hero12目前血量为：20
# 吕布攻击hero12
# hero12剩余血量为：10
# ***********************************
# hero12
# 攻击力为：15
# 吕布目前血量为：430
# hero12攻击吕布
# 吕布剩余血量为：415
# ***********************************
# 吕布
# 攻击力为：10
# hero12目前血量为：10
# 吕布攻击hero12
# hero12剩余血量为：0
# ***********************************
# ====================第13位英雄失败逃跑====================
# ======================第14位英雄出场======================
# hero13
# 攻击力为：15
# 吕布目前血量为：415
# hero13攻击吕布
# 吕布剩余血量为：400
# ***********************************
# 吕布
# 攻击力为：10
# hero13目前血量为：30
# 吕布攻击hero13
# hero13剩余血量为：20
# ***********************************
# hero13
# 攻击力为：15
# 吕布目前血量为：400
# hero13攻击吕布
# 吕布剩余血量为：385
# ***********************************
# 吕布
# 攻击力为：10
# hero13目前血量为：20
# 吕布攻击hero13
# hero13剩余血量为：10
# ***********************************
# hero13
# 攻击力为：15
# 吕布目前血量为：385
# hero13攻击吕布
# 吕布剩余血量为：370
# ***********************************
# 吕布
# 攻击力为：10
# hero13目前血量为：10
# 吕布攻击hero13
# hero13剩余血量为：0
# ***********************************
# ====================第14位英雄失败逃跑====================
# ======================第15位英雄出场======================
# hero14
# 攻击力为：15
# 吕布目前血量为：370
# hero14攻击吕布
# 吕布剩余血量为：355
# ***********************************
# 吕布
# 攻击力为：10
# hero14目前血量为：30
# 吕布攻击hero14
# hero14剩余血量为：20
# ***********************************
# hero14
# 攻击力为：15
# 吕布目前血量为：355
# hero14攻击吕布
# 吕布剩余血量为：340
# ***********************************
# 吕布
# 攻击力为：10
# hero14目前血量为：20
# 吕布攻击hero14
# hero14剩余血量为：10
# ***********************************
# hero14
# 攻击力为：15
# 吕布目前血量为：340
# hero14攻击吕布
# 吕布剩余血量为：325
# ***********************************
# 吕布
# 攻击力为：10
# hero14目前血量为：10
# 吕布攻击hero14
# hero14剩余血量为：0
# ***********************************
# ====================第15位英雄失败逃跑====================
# ======================第16位英雄出场======================
# hero15
# 攻击力为：15
# 吕布目前血量为：325
# hero15攻击吕布
# 吕布剩余血量为：310
# ***********************************
# 吕布
# 攻击力为：10
# hero15目前血量为：30
# 吕布攻击hero15
# hero15剩余血量为：20
# ***********************************
# hero15
# 攻击力为：15
# 吕布目前血量为：310
# hero15攻击吕布
# 吕布剩余血量为：295
# ***********************************
# 吕布
# 攻击力为：10
# hero15目前血量为：20
# 吕布攻击hero15
# hero15剩余血量为：10
# ***********************************
# hero15
# 攻击力为：15
# 吕布目前血量为：295
# hero15攻击吕布
# 吕布剩余血量为：280
# ***********************************
# 吕布
# 攻击力为：10
# hero15目前血量为：10
# 吕布攻击hero15
# hero15剩余血量为：0
# ***********************************
# ====================第16位英雄失败逃跑====================
# ======================第17位英雄出场======================
# hero16
# 攻击力为：15
# 吕布目前血量为：280
# hero16攻击吕布
# 吕布剩余血量为：265
# ***********************************
# 吕布
# 攻击力为：10
# hero16目前血量为：30
# 吕布攻击hero16
# hero16剩余血量为：20
# ***********************************
# hero16
# 攻击力为：15
# 吕布目前血量为：265
# hero16攻击吕布
# 吕布剩余血量为：250
# ***********************************
# 吕布
# 攻击力为：10
# hero16目前血量为：20
# 吕布攻击hero16
# hero16剩余血量为：10
# ***********************************
# hero16
# 攻击力为：15
# 吕布目前血量为：250
# hero16攻击吕布
# 吕布剩余血量为：235
# ***********************************
# 吕布
# 攻击力为：10
# hero16目前血量为：10
# 吕布攻击hero16
# hero16剩余血量为：0
# ***********************************
# ====================第17位英雄失败逃跑====================
# ======================第18位英雄出场======================
# hero17
# 攻击力为：15
# 吕布目前血量为：235
# hero17攻击吕布
# 吕布剩余血量为：220
# ***********************************
# 吕布
# 攻击力为：10
# hero17目前血量为：30
# 吕布攻击hero17
# hero17剩余血量为：20
# ***********************************
# hero17
# 攻击力为：15
# 吕布目前血量为：220
# hero17攻击吕布
# 吕布剩余血量为：205
# ***********************************
# 吕布
# 攻击力为：10
# hero17目前血量为：20
# 吕布攻击hero17
# hero17剩余血量为：10
# ***********************************
# hero17
# 攻击力为：15
# 吕布目前血量为：205
# hero17攻击吕布
# 吕布剩余血量为：190
# ***********************************
# 吕布
# 攻击力为：10
# hero17目前血量为：10
# 吕布攻击hero17
# hero17剩余血量为：0
# ***********************************
# ====================第18位英雄失败逃跑====================
# ======================第19位英雄出场======================
# hero18
# 攻击力为：15
# 吕布目前血量为：190
# hero18攻击吕布
# 吕布剩余血量为：175
# ***********************************
# 吕布
# 攻击力为：10
# hero18目前血量为：30
# 吕布攻击hero18
# hero18剩余血量为：20
# ***********************************
# hero18
# 攻击力为：15
# 吕布目前血量为：175
# hero18攻击吕布
# 吕布剩余血量为：160
# ***********************************
# 吕布
# 攻击力为：10
# hero18目前血量为：20
# 吕布攻击hero18
# hero18剩余血量为：10
# ***********************************
# hero18
# 攻击力为：15
# 吕布目前血量为：160
# hero18攻击吕布
# 吕布剩余血量为：145
# ***********************************
# 吕布
# 攻击力为：10
# hero18目前血量为：10
# 吕布攻击hero18
# hero18剩余血量为：0
# ***********************************
# ====================第19位英雄失败逃跑====================
# ======================第20位英雄出场======================
# hero19
# 攻击力为：15
# 吕布目前血量为：145
# hero19攻击吕布
# 吕布剩余血量为：130
# ***********************************
# 吕布
# 攻击力为：10
# hero19目前血量为：30
# 吕布攻击hero19
# hero19剩余血量为：20
# ***********************************
# hero19
# 攻击力为：15
# 吕布目前血量为：130
# hero19攻击吕布
# 吕布剩余血量为：115
# ***********************************
# 吕布
# 攻击力为：10
# hero19目前血量为：20
# 吕布攻击hero19
# hero19剩余血量为：10
# ***********************************
# hero19
# 攻击力为：15
# 吕布目前血量为：115
# hero19攻击吕布
# 吕布剩余血量为：100
# ***********************************
# 吕布
# 攻击力为：10
# hero19目前血量为：10
# 吕布攻击hero19
# hero19剩余血量为：0
# ***********************************
# ====================第20位英雄失败逃跑====================
# ======================第21位英雄出场======================
# hero20
# 攻击力为：15
# 吕布目前血量为：100
# hero20攻击吕布
# 吕布剩余血量为：85
# ***********************************
# 吕布
# 攻击力为：10
# hero20目前血量为：30
# 吕布攻击hero20
# hero20剩余血量为：20
# ***********************************
# hero20
# 攻击力为：15
# 吕布目前血量为：85
# hero20攻击吕布
# 吕布剩余血量为：70
# ***********************************
# 吕布
# 攻击力为：10
# hero20目前血量为：20
# 吕布攻击hero20
# hero20剩余血量为：10
# ***********************************
# hero20
# 攻击力为：15
# 吕布目前血量为：70
# hero20攻击吕布
# 吕布剩余血量为：55
# ***********************************
# 吕布
# 攻击力为：10
# hero20目前血量为：10
# 吕布攻击hero20
# hero20剩余血量为：0
# ***********************************
# ====================第21位英雄失败逃跑====================
# ======================第22位英雄出场======================
# hero21
# 攻击力为：15
# 吕布目前血量为：55
# hero21攻击吕布
# 吕布剩余血量为：40
# ***********************************
# 吕布
# 攻击力为：10
# hero21目前血量为：30
# 吕布攻击hero21
# hero21剩余血量为：20
# ***********************************
# hero21
# 攻击力为：15
# 吕布目前血量为：40
# hero21攻击吕布
# 吕布剩余血量为：25
# ***********************************
# 吕布
# 攻击力为：10
# hero21目前血量为：20
# 吕布攻击hero21
# hero21剩余血量为：10
# ***********************************
# hero21
# 攻击力为：15
# 吕布目前血量为：25
# hero21攻击吕布
# 吕布剩余血量为：10
# ***********************************
# 吕布
# 攻击力为：10
# hero21目前血量为：10
# 吕布攻击hero21
# hero21剩余血量为：0
# ***********************************
# ====================第22位英雄失败逃跑====================
# ======================第23位英雄出场======================
# hero22
# 攻击力为：15
# 吕布目前血量为：10
# hero22攻击吕布
# 吕布剩余血量为：-5
# ***********************************
# 吕布老矣~~失败逃跑~~88~~
