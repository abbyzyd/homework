# %%
import numpy as np
import tensorflow as tf
import pandas as pd
import random
import math
import re
 
from sklearn import preprocessing
from os import path, listdir
from sklearn.datasets import load_svmlight_files
from sklearn.model_selection import train_test_split
from sklearn import metrics
from tensorflow.contrib import layers
 
from sklearn import metrics
 
import time
import datetime
 
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

# %% [markdown]
# # 定义输入样本格式

# %%
_CSV_COLUMNS = [
     'age', 'workclass', 'fnlwgt', 'education', 'education_num',
     'marital_status', 'occupation', 'relationship', 'race', 'gender',
     'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
     'income_bracket'
]

# %% [markdown]
# # 定义默认值

# %%
_CSV_COLUMN_DEFAULTS = [[0], [''], [0], [''], [0], [''], [''], [''], [''], [''],
                        [0], [0], [0], [''], ['']]

# %% [markdown]
# # 设置训练样本数和验证样本数

# %%
_NUM_EXAMPLES = {
    'train': 32561,
    'validation': 16281,
}

# %% [markdown]
# # 定义特征处理函数

# %%
"""Builds a set of wide and deep feature columns."""
def build_model_columns():
    # 1. 特征处理，包括：连续特征、离散特征、转换特征、交叉特征等
 
    # 连续特征 （其中在Wide和Deep组件都会用到）
    age = tf.feature_column.numeric_column('age')
    education_num = tf.feature_column.numeric_column('education_num')
    capital_gain = tf.feature_column.numeric_column('capital_gain')
    capital_loss = tf.feature_column.numeric_column('capital_loss')
    hours_per_week = tf.feature_column.numeric_column('hours_per_week')
 
    # 离散特征
    education = tf.feature_column.categorical_column_with_vocabulary_list(
        'education', [
            'Bachelors', 'HS-grad', '11th', 'Masters', '9th', 'Some-college',
            'Assoc-acdm', 'Assoc-voc', '7th-8th', 'Doctorate', 'Prof-school',
            '5th-6th', '10th', '1st-4th', 'Preschool', '12th'])
 
    marital_status = tf.feature_column.categorical_column_with_vocabulary_list(
        'marital_status', [
            'Married-civ-spouse', 'Divorced', 'Married-spouse-absent',
            'Never-married', 'Separated', 'Married-AF-spouse', 'Widowed'])
 
    relationship = tf.feature_column.categorical_column_with_vocabulary_list(
        'relationship', [
            'Husband', 'Not-in-family', 'Wife', 'Own-child', 'Unmarried',
            'Other-relative'])
 
    workclass = tf.feature_column.categorical_column_with_vocabulary_list(
        'workclass', [
            'Self-emp-not-inc', 'Private', 'State-gov', 'Federal-gov',
            'Local-gov', '?', 'Self-emp-inc', 'Without-pay', 'Never-worked'])
 
    # 离散hash bucket特征
    occupation = tf.feature_column.categorical_column_with_hash_bucket(
        'occupation', hash_bucket_size=1000
    )
 
    # 特征Transformations
    age_buckets = tf.feature_column.bucketized_column(
        age, boundaries=[18, 25, 30, 35, 40, 45, 50, 55, 60, 65]
    )
 
    # 2. 设定Wide层特征
    """
    Wide部分使用了规范化后的连续特征、离散特征、交叉特征
    """
    # 基本特征列
    base_columns = [
        # 全是离散特征
        education, marital_status, relationship, workclass, occupation,
        age_buckets,
    ]
 
    # 交叉特征列
    crossed_columns = [
        tf.feature_column.crossed_column(
            ['education', 'occupation'], hash_bucket_size=1000),
        tf.feature_column.crossed_column(
            [age_buckets, 'education', 'occupation'], hash_bucket_size=1000
        )
    ]
 
    # wide特征列
    wide_columns = base_columns + crossed_columns
 
    # 3. 设定Deep层特征
    """
    Deep层主要针对离散特征进行处理，其中处理方式有：
    1. Sparse Features -> Embedding vector -> 串联(连续特征)，其中Embedding Values随机初始化。
    2. 另外一种处理离散特征的方法是：one-hot和multi-hot representation. 此方法适用于低维度特征，其中embedding是通用的做法
    其中：采用embedding_column(embedding)和indicator_column(multi-hot)API
    """
    # deep特征列
    deep_columns = [
        age,
        education_num,
        capital_gain,
        capital_loss,
        hours_per_week,
        tf.feature_column.indicator_column(workclass),
        tf.feature_column.indicator_column(education),
        tf.feature_column.indicator_column(marital_status),
        tf.feature_column.indicator_column(relationship),
 
        # embedding特征
        tf.feature_column.embedding_column(occupation, dimension=8)
    ]
    return wide_columns, deep_columns

# %% [markdown]
# # 定义训练/测试数据输入函数

# %%
def input_fn(data_file, num_epochs, shuffle, batch_size):
    """为Estimator创建一个input function"""
    #assert判断，为False时执行后面语句
    assert tf.gfile.Exists(data_file), "{0} not found.".format(data_file)
    def parse_csv(line):
        print("Parsing", data_file)
        # tf.decode_csv会把csv文件转换成Tensor。其中record_defaults用于指明每一列的缺失值用什么填充。
        columns = tf.decode_csv(line, record_defaults=_CSV_COLUMN_DEFAULTS)
        features = dict(zip(_CSV_COLUMNS, columns))
        #pop函数提取label
        labels = features.pop('income_bracket')
        # tf.equal(x, y) 返回一个bool类型Tensor， 表示x == y, element-wise
        return features, tf.equal(labels, '>50K') 
    dataset = tf.data.TextLineDataset(data_file).map(parse_csv, num_parallel_calls=5)
    '''
    使用 tf.data.Dataset.map，我们可以很方便地对数据集中的各个元素进行预处理。
    map接收一个函数，Dataset中的每个元素都会被当作这个函数的输入，并将函数返回值作为新的Dataset
    因为输入元素之间时独立的，所以可以在多个 CPU 核心上并行地进行预处理。
    num_parallel_calls 参数的最优值取决于你的硬件、训练数据的特质（比如：它的 size、shape）、
    map 函数的计算量 和 CPU 上同时进行的其它处理。比较简单的一个设置方法是：将 num_parallel_calls 设置为 CPU 的核心数。
    例如，CPU 有四个核心时，将 num_parallel_calls 设置为 4 将会很高效。
    相反，如果 num_parallel_calls 大于 CPU 的核心数，将导致低效的调度，导致输入管道的性能下降。
    
    也可以设置shuffle
    shuffle的功能为打乱dataset中的元素，它有一个参数buffersize，表示打乱时使用的buffer的大小，建议舍的不要太小，一般是1000
    '''
   
    dataset = dataset.repeat(num_epochs)
    #repeat的功能就是将整个序列重复多次，主要用来处理机器学习中的epoch，假设原先的数据是一个epoch，使用repeat(2)就可以将之变成2个epoch
    dataset = dataset.batch(batch_size)
    '''
    batch是机器学习中批量梯度下降法(Batch Gradient Descent, BGD)的概念，
    在每次梯度下降的时候取batch-size的数据量做平均来获取梯度下降方向，
    例如我们将batch-size设为2，那么每次iterator都会得到2个数据
    '''
    iterator = dataset.make_one_shot_iterator()
    batch_features, batch_labels = iterator.get_next()
    return batch_features, batch_labels

# %% [markdown]
# # 定义Wide & Deep模型

# %%
# Wide & Deep Model
def build_estimator(model_dir, model_type):
    """Build an estimator appropriate for the given model type."""
    wide_columns, deep_columns = build_model_columns()
    hidden_units = [100, 50]
 
    # Create a tf.estimator.RunConfig to ensure the model is run on CPU, which
    # trains faster than GPU for this model.
    run_config = tf.estimator.RunConfig().replace(
      session_config=tf.ConfigProto(device_count={'GPU': 0}))
 
    if model_type == 'wide':
        return tf.estimator.LinearClassifier(
          model_dir=model_dir,
          feature_columns=wide_columns,
          config=run_config)
    elif model_type == 'deep':
        return tf.estimator.DNNClassifier(
          model_dir=model_dir,
          feature_columns=deep_columns,
          hidden_units=hidden_units,
          config=run_config)
    else:
        return tf.estimator.DNNLinearCombinedClassifier(
          model_dir=model_dir,
          linear_feature_columns=wide_columns,
          dnn_feature_columns=deep_columns,
          dnn_hidden_units=hidden_units,
          config=run_config)

# %%
# 模型路径
model_type = 'widedeep'
model_dir = 'D:\\KaiKeBa\\基础班\\Python\\第六章\\第七节\\widedeep'
 
# Wide & Deep 联合模型
model = build_estimator(model_dir, model_type)
 
 
# ## 4）模型训练
 
# In[11]:
 
# 训练参数
train_epochs = 10
batch_size = 5000
train_file = 'D:\\KaiKeBa\\基础班\\Python\\第六章\\第七节\\data\\adult.data'
test_file = 'D:\\KaiKeBa\\基础班\\Python\\第六章\\第七节\\data\\adult.test'
 
# 6. 开始训练
for n in range(train_epochs):
    # 模型训练
    model.train(input_fn=lambda: input_fn(train_file, train_epochs, True, batch_size))
    # 模型评估
    results = model.evaluate(input_fn=lambda: input_fn(test_file, 1, False, batch_size))
    # 打印评估结果
    print("Results at epoch {0}".format((n+1) * train_epochs))
    print('-'*30)
    for key in sorted(results):
        print("{0:20}: {1:.4f}".format(key, results[key]))
# Out:
# INFO:tensorflow:Using config: {'_model_dir': 'D:\\KaiKeBa\\基础班\\Python\\第六章\\第七节\\widedeep', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': device_count {
#   key: "GPU"
#   value: 0
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000000001A2E0780>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# Parsing D:\KaiKeBa\基础班\Python\第六章\第七节\data\adult.data
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt.
# INFO:tensorflow:loss = 947913.4, step = 1
# INFO:tensorflow:Saving checkpoints for 66 into D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt.
# INFO:tensorflow:Loss for final step: 1.2464942.
# Parsing D:\KaiKeBa\基础班\Python\第六章\第七节\data\adult.test
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-07-07T20:21:58Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt-66
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2020-07-07-20:21:59
# INFO:tensorflow:Saving dict for global step 66: accuracy = 1.0, accuracy_baseline = 1.0, auc = 1.0, auc_precision_recall = 0.0, average_loss = 0.0022849583, global_step = 66, label/mean = 0.0, loss = 9.300351, precision = 0.0, prediction/mean = 0.0022728522, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 66: D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt-66
# Results at epoch 10
# ------------------------------
# accuracy            : 1.0000
# accuracy_baseline   : 1.0000
# auc                 : 1.0000
# auc_precision_recall: 0.0000
# average_loss        : 0.0023
# global_step         : 66.0000
# label/mean          : 0.0000
# loss                : 9.3004
# precision           : 0.0000
# prediction/mean     : 0.0023
# recall              : 0.0000
# Parsing D:\KaiKeBa\基础班\Python\第六章\第七节\data\adult.data
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt-66
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 66 into D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt.
# INFO:tensorflow:loss = 10.934526, step = 67
# INFO:tensorflow:Saving checkpoints for 132 into D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.9590415.
# Parsing D:\KaiKeBa\基础班\Python\第六章\第七节\data\adult.test
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-07-07T20:22:14Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt-132
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2020-07-07-20:22:15
# INFO:tensorflow:Saving dict for global step 132: accuracy = 1.0, accuracy_baseline = 1.0, auc = 1.0, auc_precision_recall = 0.0, average_loss = 0.0017655226, global_step = 132, label/mean = 0.0, loss = 7.1861186, precision = 0.0, prediction/mean = 0.0017576204, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 132: D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt-132
# Results at epoch 20
# ------------------------------
# accuracy            : 1.0000
# accuracy_baseline   : 1.0000
# auc                 : 1.0000
# auc_precision_recall: 0.0000
# average_loss        : 0.0018
# global_step         : 132.0000
# label/mean          : 0.0000
# loss                : 7.1861
# precision           : 0.0000
# prediction/mean     : 0.0018
# recall              : 0.0000
# Parsing D:\KaiKeBa\基础班\Python\第六章\第七节\data\adult.data
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt-132
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 132 into D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt.
# INFO:tensorflow:loss = 8.412618, step = 133
# INFO:tensorflow:Saving checkpoints for 198 into D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.7737816.
# Parsing D:\KaiKeBa\基础班\Python\第六章\第七节\data\adult.test
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-07-07T20:22:30Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt-198
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2020-07-07-20:22:31
# INFO:tensorflow:Saving dict for global step 198: accuracy = 1.0, accuracy_baseline = 1.0, auc = 1.0, auc_precision_recall = 0.0, average_loss = 0.0014295942, global_step = 198, label/mean = 0.0, loss = 5.818806, precision = 0.0, prediction/mean = 0.0014240228, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 198: D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt-198
# Results at epoch 30
# ------------------------------
# accuracy            : 1.0000
# accuracy_baseline   : 1.0000
# auc                 : 1.0000
# auc_precision_recall: 0.0000
# average_loss        : 0.0014
# global_step         : 198.0000
# label/mean          : 0.0000
# loss                : 5.8188
# precision           : 0.0000
# prediction/mean     : 0.0014
# recall              : 0.0000
# Parsing D:\KaiKeBa\基础班\Python\第六章\第七节\data\adult.data
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt-198
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 198 into D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt.
# INFO:tensorflow:loss = 6.785872, step = 199
# INFO:tensorflow:Saving checkpoints for 264 into D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.643148.
# Parsing D:\KaiKeBa\基础班\Python\第六章\第七节\data\adult.test
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-07-07T20:22:46Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt-264
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2020-07-07-20:22:47
# INFO:tensorflow:Saving dict for global step 264: accuracy = 1.0, accuracy_baseline = 1.0, auc = 0.99999994, auc_precision_recall = 0.0, average_loss = 0.0011924368, global_step = 264, label/mean = 0.0, loss = 4.8535156, precision = 0.0, prediction/mean = 0.0011883103, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 264: D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt-264
# Results at epoch 40
# ------------------------------
# accuracy            : 1.0000
# accuracy_baseline   : 1.0000
# auc                 : 1.0000
# auc_precision_recall: 0.0000
# average_loss        : 0.0012
# global_step         : 264.0000
# label/mean          : 0.0000
# loss                : 4.8535
# precision           : 0.0000
# prediction/mean     : 0.0012
# recall              : 0.0000
# Parsing D:\KaiKeBa\基础班\Python\第六章\第七节\data\adult.data
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt-264
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 264 into D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt.
# INFO:tensorflow:loss = 5.6420193, step = 265
# INFO:tensorflow:Saving checkpoints for 330 into D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.5485341.
# Parsing D:\KaiKeBa\基础班\Python\第六章\第七节\data\adult.test
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-07-07T20:23:02Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt-330
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2020-07-07-20:23:04
# INFO:tensorflow:Saving dict for global step 330: accuracy = 1.0, accuracy_baseline = 1.0, auc = 0.99999994, auc_precision_recall = 0.0, average_loss = 0.0010197813, global_step = 330, label/mean = 0.0, loss = 4.150765, precision = 0.0, prediction/mean = 0.0010166029, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 330: D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt-330
# Results at epoch 50
# ------------------------------
# accuracy            : 1.0000
# accuracy_baseline   : 1.0000
# auc                 : 1.0000
# auc_precision_recall: 0.0000
# average_loss        : 0.0010
# global_step         : 330.0000
# label/mean          : 0.0000
# loss                : 4.1508
# precision           : 0.0000
# prediction/mean     : 0.0010
# recall              : 0.0000
# Parsing D:\KaiKeBa\基础班\Python\第六章\第七节\data\adult.data
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt-330
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 330 into D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt.
# INFO:tensorflow:loss = 4.8117247, step = 331
# INFO:tensorflow:Saving checkpoints for 396 into D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.47308543.
# Parsing D:\KaiKeBa\基础班\Python\第六章\第七节\data\adult.test
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-07-07T20:23:18Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt-396
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2020-07-07-20:23:20
# INFO:tensorflow:Saving dict for global step 396: accuracy = 1.0, accuracy_baseline = 1.0, auc = 1.0, auc_precision_recall = 0.0, average_loss = 0.0008819476, global_step = 396, label/mean = 0.0, loss = 3.5897472, precision = 0.0, prediction/mean = 0.0008794475, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 396: D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt-396
# Results at epoch 60
# ------------------------------
# accuracy            : 1.0000
# accuracy_baseline   : 1.0000
# auc                 : 1.0000
# auc_precision_recall: 0.0000
# average_loss        : 0.0009
# global_step         : 396.0000
# label/mean          : 0.0000
# loss                : 3.5897
# precision           : 0.0000
# prediction/mean     : 0.0009
# recall              : 0.0000
# Parsing D:\KaiKeBa\基础班\Python\第六章\第七节\data\adult.data
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt-396
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 396 into D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt.
# INFO:tensorflow:loss = 4.150982, step = 397
# INFO:tensorflow:Saving checkpoints for 462 into D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.4116859.
# Parsing D:\KaiKeBa\基础班\Python\第六章\第七节\data\adult.test
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-07-07T20:23:35Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt-462
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2020-07-07-20:23:36
# INFO:tensorflow:Saving dict for global step 462: accuracy = 1.0, accuracy_baseline = 1.0, auc = 1.0, auc_precision_recall = 0.0, average_loss = 0.00076931744, global_step = 462, label/mean = 0.0, loss = 3.1313143, precision = 0.0, prediction/mean = 0.0007673203, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 462: D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt-462
# Results at epoch 70
# ------------------------------
# accuracy            : 1.0000
# accuracy_baseline   : 1.0000
# auc                 : 1.0000
# auc_precision_recall: 0.0000
# average_loss        : 0.0008
# global_step         : 462.0000
# label/mean          : 0.0000
# loss                : 3.1313
# precision           : 0.0000
# prediction/mean     : 0.0008
# recall              : 0.0000
# Parsing D:\KaiKeBa\基础班\Python\第六章\第七节\data\adult.data
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt-462
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 462 into D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt.
# INFO:tensorflow:loss = 3.6103187, step = 463
# INFO:tensorflow:Saving checkpoints for 528 into D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.36167416.
# Parsing D:\KaiKeBa\基础班\Python\第六章\第七节\data\adult.test
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-07-07T20:23:51Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt-528
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2020-07-07-20:23:52
# INFO:tensorflow:Saving dict for global step 528: accuracy = 1.0, accuracy_baseline = 1.0, auc = 0.99999994, auc_precision_recall = 0.0, average_loss = 0.00067761197, global_step = 528, label/mean = 0.0, loss = 2.7580502, precision = 0.0, prediction/mean = 0.0006759899, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 528: D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt-528
# Results at epoch 80
# ------------------------------
# accuracy            : 1.0000
# accuracy_baseline   : 1.0000
# auc                 : 1.0000
# auc_precision_recall: 0.0000
# average_loss        : 0.0007
# global_step         : 528.0000
# label/mean          : 0.0000
# loss                : 2.7581
# precision           : 0.0000
# prediction/mean     : 0.0007
# recall              : 0.0000
# Parsing D:\KaiKeBa\基础班\Python\第六章\第七节\data\adult.data
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt-528
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 528 into D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt.
# INFO:tensorflow:loss = 3.1714902, step = 529
# INFO:tensorflow:Saving checkpoints for 594 into D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.3206913.
# Parsing D:\KaiKeBa\基础班\Python\第六章\第七节\data\adult.test
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-07-07T20:24:07Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt-594
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2020-07-07-20:24:09
# INFO:tensorflow:Saving dict for global step 594: accuracy = 1.0, accuracy_baseline = 1.0, auc = 1.0, auc_precision_recall = 0.0, average_loss = 0.00060222973, global_step = 594, label/mean = 0.0, loss = 2.4512255, precision = 0.0, prediction/mean = 0.0006008923, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 594: D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt-594
# Results at epoch 90
# ------------------------------
# accuracy            : 1.0000
# accuracy_baseline   : 1.0000
# auc                 : 1.0000
# auc_precision_recall: 0.0000
# average_loss        : 0.0006
# global_step         : 594.0000
# label/mean          : 0.0000
# loss                : 2.4512
# precision           : 0.0000
# prediction/mean     : 0.0006
# recall              : 0.0000
# Parsing D:\KaiKeBa\基础班\Python\第六章\第七节\data\adult.data
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt-594
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 594 into D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt.
# INFO:tensorflow:loss = 2.8127384, step = 595
# INFO:tensorflow:Saving checkpoints for 660 into D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.28666416.
# Parsing D:\KaiKeBa\基础班\Python\第六章\第七节\data\adult.test
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-07-07T20:24:25Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt-660
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2020-07-07-20:24:27
# INFO:tensorflow:Saving dict for global step 660: accuracy = 1.0, accuracy_baseline = 1.0, auc = 1.0, auc_precision_recall = 0.0, average_loss = 0.0005395104, global_step = 660, label/mean = 0.0, loss = 2.1959422, precision = 0.0, prediction/mean = 0.00053839566, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 660: D:\KaiKeBa\基础班\Python\第六章\第七节\widedeep\model.ckpt-660
# Results at epoch 100
# ------------------------------
# accuracy            : 1.0000
# accuracy_baseline   : 1.0000
# auc                 : 1.0000
# auc_precision_recall: 0.0000
# average_loss        : 0.0005
# global_step         : 660.0000
# label/mean          : 0.0000
# loss                : 2.1959
# precision           : 0.0000
# prediction/mean     : 0.0005
# recall              : 0.0000
